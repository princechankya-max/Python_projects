# %%
import pandas as pd

data = [1,3,6,6,8,4,]

df = pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  3
# 2  6
# 3  6
# 4  8
# 5  4

# %%
import matplotlib.pyplot as plt

plt.plot([1,7,3],[6,5,6])
plt.show()
